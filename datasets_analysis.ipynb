# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# VIDEO GAMES SELLING.

# %%
video_game = pd.read_csv('data/datasets_analysis/video_games.csv', index_col='Rank')
video_game.sample(5)
# Out:
#                                    Title       Sales            Series  \
# Rank
# 38.0  Pokémon Diamond / Pearl / Platinum  24,730,000           Pokémon
# 29.0                    The Walking Dead  28,000,000  The Walking Dead
# 18.0               New Super Mario Bros.  30,800,000       Super Mario
# 46.0                       Mario Kart DS  23,600,000        Mario Kart
# 37.0                 Grand Theft Auto IV  25,000,000  Grand Theft Auto
#
#          Platform(s) Initial release date Developer(s)[a]  \
# Rank
# 38.0     Nintendo DS   September 28, 2006      Game Freak
# 29.0  Multi-platform       April 24, 2012  Telltale Games
# 18.0     Nintendo DS            15.May.06    Nintendo EAD
# 46.0     Nintendo DS    November 14, 2005    Nintendo EAD
# 37.0  Multi-platform       April 29, 2008  Rockstar North
#
#                      Publisher(s)[a]
# Rank
# 38.0  Nintendo / The Pokémon Company
# 29.0                  Telltale Games
# 18.0                        Nintendo
# ...

# %%
video_game.shape
# Out:
# (49, 7)

# %%
video_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 49 entries, 1.0 to 49.0
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Title                 49 non-null     object
#  1   Sales                 43 non-null     object
#  2   Series                49 non-null     object
#  3   Platform(s)           49 non-null     object
#  4   Initial release date  49 non-null     object
#  5   Developer(s)[a]       49 non-null     object
#  6   Publisher(s)[a]       49 non-null     object
# dtypes: object(7)
# memory usage: 3.1+ KB

# %%
video_game.describe()
# Out:
#             Title       Sales       Series     Platform(s)  \
# count          49          43           49              49
# unique         49          42           23              17
# top     Minecraft  23,000,000  Super Mario  Multi-platform
# freq            1           2            6              19
#
#         Initial release date Developer(s)[a] Publisher(s)[a]
# count                     49              49              49
# unique                    49              27              18
# top     November 18, 2011[d]    Nintendo EAD        Nintendo
# freq                       1              12              21

# %%
plt.xticks(rotation=90)
# plt.xticks(rotation = 45, ha='right')
sns.countplot(video_game['Series'])
# Out:
# e:\programming data\data_science\DL\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Series', ylabel='count'>

# %%
plt.xticks(rotation=90)
sns.countplot(video_game['Developer(s)[a]'])
# Out:
# e:\programming data\data_science\DL\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Developer(s)[a]', ylabel='count'>

# %%
plt.xticks(rotation=90)
sns.countplot(video_game['Platform(s)'])
# Out:
# e:\programming data\data_science\DL\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Platform(s)', ylabel='count'>

# %%
plt.xticks(rotation=90)
sns.scatterplot(x='Publisher(s)[a]', y='Developer(s)[a]', data=video_game)
# Out:
# <AxesSubplot:xlabel='Publisher(s)[a]', ylabel='Developer(s)[a]'>

# %% [markdown]
# DIAMOND DATASETS.

# %%
diamond = pd.read_csv('data/datasets_analysis/diamonds.csv')
diamond.sample(5)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 19158   1.11      Ideal     G     VS1   61.6   56.0   7917  6.64  6.67  4.10
# 52060   0.70      Ideal     E     SI2   62.1   56.0   2453  5.65  5.68  3.52
# 49430   0.70      Ideal     H     SI1   61.1   58.0   2107  5.69  5.70  3.48
# 14944   1.20  Very Good     H     SI1   61.0   58.0   6019  6.84  6.92  4.20
# 37140   0.40  Very Good     F    VVS2   62.9   55.0    972  4.72  4.75  2.98

# %%
diamond.shape
# Out:
# (53940, 10)

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamond.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
diamond.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.scatterplot(x='price', y='depth', size='carat', data=diamond)
# Out:
# <AxesSubplot:xlabel='price', ylabel='depth'>

# %% [markdown]
# CRICKET DATA.

# %%
bat_odi = pd.read_csv('data/datasets_analysis/Batting/ODI data.csv', index_col=0)
bat_odi.sample(5)
# Out:
#                      Player       Span  Mat Inns NO Runs  HS    Ave   BF  \
# 39  Sarandeep Singh (INDIA)  2002-2003    5    4  1   47  19  15.66   73
# 35        PWH de Silva (SL)  2017-2019   12   10  2  115  30  14.37  111
# 4         R Mutumbami (ZIM)  2014-2019   33   31  2  582  74  20.06  814
# 23           CM Wells (ENG)  1985-1985    2    2  0   22  17  11.00   44
# 7      Raees Ahmadzai (AFG)  2009-2010    5    4  1   88  39  29.33  137
#
#        SR 100 50  0  Unnamed: 13
# 39  64.38   0  0  0          NaN
# 35  103.6   0  0  2          NaN
# 4   71.49   0  3  3          NaN
# 23   50.0   0  0  0          NaN
# 7   64.23   0  0  0          NaN

# %%
bat_odi.shape
# Out:
# (2500, 14)

# %%
bat_odi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2500 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       2500 non-null   object
#  1   Span         2500 non-null   object
#  2   Mat          2500 non-null   int64
#  3   Inns         2500 non-null   object
#  4   NO           2500 non-null   object
#  5   Runs         2500 non-null   object
#  6   HS           2500 non-null   object
#  7   Ave          2500 non-null   object
#  8   BF           2500 non-null   object
#  9   SR           2500 non-null   object
#  10  100          2500 non-null   object
#  11  50           2500 non-null   object
#  12  0            2500 non-null   object
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 293.0+ KB

# %%
bat_odi.groupby(['Span', 'Player']).
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_14916\3697618286.py", line 1
#     bat_odi.groupby(['Span', 'Player']).
#                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# DIABETES DATA.

# %%
diab = pd.read_csv('data/datasets_analysis/diabetes.csv')
diab.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 444            4      117             62             12        0  29.7
# 539            3      129             92             49      155  36.4
# 16             0      118             84             47      230  45.8
# 628            5      128             80              0        0  34.6
# 247            0      165             90             33      680  52.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 444                     0.380   30        1
# 539                     0.968   32        1
# 16                      0.551   31        1
# 628                     0.144   45        0
# 247                     0.427   23        0

# %%
diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diab.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...
